# %% [markdown]
# # 進階的 SQL 五十道練習
#
# > 資料定義語言
#
# [數聚點](https://www.datainpoint.com) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %%
%LOAD mysql user=root password=hahowsql

# %% [markdown]
# ## （複習）SQL 的分類
#
# - 在初階課程「SQL 的五十道練習」中我們專注在資料查詢語言的部分；這堂進階課程會完整帶學員們認識其他的 SQL 語言。
# - 實務上，資料查詢語言是被分類在資料操作語言之下的一個分支。
#     - **資料定義語言（Data Definition Language, DDL）**
#     - 資料操作語言（Data Manipulation Language, DML）
#         - 資料查詢語言（Data Query Language, DQL）
#     - 資料控制語言（Data Control Language, DCL）
#     - 交易控制語言（Transaction Control Language, TCL）

# %% [markdown]
# ## 資料定義語言（Data Definition Language, DDL）主要的保留字
#
# - `CREATE`
# - `TRUNCATE`
# - `DROP`
# - `ALTER`
#
# 這意味著我們可以在關聯式資料庫管理系統中創造、刪除與更新物件。

# %% [markdown]
# ## 有哪些物件可以被創造、刪除與更新
#
# - 資料庫（Database）。
# - 資料表（Table）。
# - 檢視表（View）。
# - 角色（Role）與使用者（User）。

# %% [markdown]
# ## 資料庫（Database）

# %% [markdown]
# ## 以 `CREATE DATABASE` 創造資料庫
#
# - 執行之後可以在左側資料庫按右鍵下拉式選單點選 Refresh 即可檢視資料庫是否被創造。
# - 或者使用 `SHOW DATABASES;` 指令檢視。
#
# ```sql
# CREATE DATABASE database_name;
# ```

# %%
CREATE DATABASE cloned_imdb;

# %% [markdown]
# ## 關聯式資料庫管理系統不允許相同命名的資料庫
#
# 如果我們再執行一次前述的 `CREATE DATABASE database_name;` 指令會得到錯誤。

# %% [markdown]
# ## 以 `DROP DATABASE` 刪除資料庫
#
# - 執行之後可以在左側資料庫按右鍵下拉式選單點選 Refresh 即可檢視資料庫是否被刪除。
# - 或者使用 `SHOW DATABASES;` 指令檢視。
#
# ```sql
# DROP DATABASE db_name;
# ```

# %%
DROP DATABASE cloned_imdb;

# %% [markdown]
# ## 資料庫不存在時不允許刪除
#
# 如果我們再執行一次前述的 `DROP DATABASE database_name;` 指令會得到錯誤。

# %% [markdown]
# ## 加入 `IF EXISTS`
#
# 在加入 `IF EXISTS` 的情況下，可以避免得到錯誤。
#
# ```sql
# DROP DATABASE IF EXISTS database_name;
# ```

# %%
DROP DATABASE IF EXISTS cloned_imdb;

# %% [markdown]
# ## 連線工具的使用者介面也可以輕鬆創造、刪除資料庫
#
# - 左側資料庫按右鍵下拉式選單點選 Create New Database
# - 選擇 Charset 與 Collation
#     - Charset: utf8mb4
#     - Collation: utf8mb4_unicode_ci
# - 左側資料庫按右鍵下拉式選單點選 Delete

# %% [markdown]
# ## 什麼是 Charset 與 Collation
#
# - MySQL utf8 並不是一般常用的 utf8 編碼，而是 utf8mb3(most bytes 3)
# - MySQL utf8mb4(most bytes 4)對應到一般常用的 utf8 編碼，可以顯示冷僻字或者表情符號（Emoji）
# - Collation 影響文字資料的排序以及搜尋：utf8mb4_unicode_ci 準確但比較慢 utf8mb4_general_ci 速度快但相對不準確。

# %% [markdown]
# ## 在 `CREATE DATABASE` 加入 Character Set 與 Collation
#
# ```sql
# CREATE DATABASE database_name CHARACTER SET charset_name COLLATE collate_name;
# ```

# %%
CREATE DATABASE cloned_imdb CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;

# %% [markdown]
# ## 資料表（Table）

# %% [markdown]
# ## 以 `CREATE TABLE` 創造資料表
#
# - 執行之後可以在左側資料庫按右鍵下拉式選單點選 Refresh 即可檢視資料表是否被創造。
# - 或者使用 `SHOW TABLES FROM database_name;` 指令檢視。
#
# ```sql
# CREATE TABLE database_name.table_name (
#     column_name_1 datatype,
#     column_name_2 datatype,
#     column_name_3 datatype,
#     ....
# );
# ```

# %%
CREATE TABLE cloned_imdb.movies (
    id int,
    title varchar(200),
    rating float,
    release_year year
);

# %% [markdown]
# ## MySQL 的資料類型
#
# - 整數。
# - 浮點數。
# - 文字。
# - 日期與時間。

# %% [markdown]
# ## MySQL 的整數資料類型
#
# - `tinyint`: $-2^{7} \text{ 到 } 2^{7} - 1$（用 8-bit 儲存整數資料）
# - `smallint`: $-2^{15} \text{ 到 } 2^{15} - 1$（用 16-bit 儲存整數資料）
# - `mediumint`: $-2^{23} \text{ 到 } 2^{23} - 1$（用 24-bit 儲存整數資料）
# - `int`: $-2^{31} \text{ 到 } 2^{31} - 1$（用 32-bit 儲存整數資料）
# - `bigint`: $-2^{63} \text{ 到 } 2^{63} - 1$（用 64-bit 儲存整數資料）

# %% [markdown]
# ## 設定是否要涵蓋小於零的負數
#
# - 可以在整數資料類型後加上 `unsigned` 註明不涵蓋小於零的負數（無號整數）。
# - 整數範圍可以多出一倍，例如 `tinyint` 為 -128 到 127，`tinyint unsigned` 會變為 0 到 255

# %% [markdown]
# ## 在資料類型為 `tinyint` 的欄位輸入 128 會出現錯誤
#
# ```
# Data truncation: Out of range value for column 'id' at row 1
# ```

# %% [markdown]
# ```sql
# DROP TABLE IF EXISTS cloned_imdb.movies;
# CREATE TABLE cloned_imdb.movies (
#     id tinyint
# );
# INSERT INTO cloned_imdb.movies (id)
# VALUES (128);
# ```

# %% [markdown]
# ## 在資料類型為 `tinyint unsigned` 的欄位輸入 128 就會成功

# %%
DROP TABLE IF EXISTS cloned_imdb.movies;

# %%
CREATE TABLE cloned_imdb.movies (
    id tinyint unsigned
);

# %%
INSERT INTO cloned_imdb.movies (id)
VALUES (128);

# %% [markdown]
# ## MySQL 的浮點數資料類型
#
# - `float`：用 32-bit 儲存浮點數資料，有效位數到小數第 7 位左右。
# - `double`：用 64-bit（`float` 的兩倍，故命名為 double precision）儲存浮點數資料，有效位數到小數第 15 位左右。

# %% [markdown]
# ## 浮點數資料類型也能指定 `unsigned`
#
# - 確保不會有負的數值輸入到該欄位。
# - 但是不影響有效浮點數範圍。
#
# ```
# Data truncation: Out of range value for column 'rating' at row 1
# ```

# %% [markdown]
# ```sql
# DROP TABLE IF EXISTS cloned_imdb.movies;
# CREATE TABLE cloned_imdb.movies (
#     id tinyint unsigned,
#     rating float unsigned
# );
# INSERT INTO cloned_imdb.movies (id, rating)
# VALUES (1, -9.2);
# ```

# %% [markdown]
# ## MySQL 的文字資料類型
#
# - `char`: 用 255-byte($2^{8} - 1$)儲存文字資料，固定長度。
# - `varchar`: 用 65,535-byte($2^{16} - 1$)儲存文字資料，可變長度。
# - `tinytext`: 用 255-byte($2^{8} - 1$)儲存文字資料，可變長度。
# - `text`: 用 65,535-byte($2^{16} - 1$)儲存文字資料，可變長度。
# - `mediumtext`: 用 16,777,215-byte($2^{24} - 1$)儲存文字資料，可變長度。
# - `longtext`: 用 4,294,967,298-byte($2^{32} - 1$)儲存文字資料，可變長度。

# %% [markdown]
# ## 如何選擇 MySQL 的文字資料類型
#
# - 多數的狀態下使用 `varchar(最大字元數)` 即可。
# - MySQL5.0 之後 `varchar` 用 65,535-byte 儲存文字資料，使得 `tinytext` 與 `text` 無用武之地。
# - 如果儲存的是文件（例如部落格網站的資料庫），可以選擇 `mediumtext` 或 `longtext`。

# %% [markdown]
# ## `char` 與 `varchar` 的差別
#
# - `char` 為固定長度，會填入空白補滿長度。
# - `varchar` 為可變長度，不會填入空白補滿長度。
# - 使用固定長度的 `char` 能提高查詢、輸入資料的效率。

# %% [markdown]
# ## 輸入超過字元長度的資料會出現錯誤
#
# ```
# Data truncation: Out of range value for column 'id' at row 1
# ```

# %% [markdown]
# ```sql
# DROP TABLE IF EXISTS cloned_imdb.movies;
# CREATE TABLE cloned_imdb.movies (
#     id int unsigned,
#     title varchar(20)
# );
# INSERT INTO cloned_imdb.movies (id, title)
# VALUES (1, 'The Shawshank Redemption');
# ```

# %% [markdown]
# ## MySQL 的日期時間資料類型
#
# - `date`: 日期 `YYYY-MM-DD`
# - `datetime`: 日期時間 `YYYY-MM-DD hh:mm:ss`
# - `time`: 時間 `hh:mm:ss`
# - `year`: 年 `YYYY`

# %% [markdown]
# ## 輸入日期時間資料類型
#
# - 只含有年份的資料直接以整數輸入。
# - 年份以外的日期時間資料，以字元格式輸入。

# %%
DROP TABLE IF EXISTS cloned_imdb.movies;

# %%
CREATE TABLE cloned_imdb.movies (
    id int unsigned,
    title varchar(200),
    release_year year,
    release_date date
);

# %%
INSERT INTO cloned_imdb.movies (id, title, release_year, release_date)
VALUES (1, 'The Shawshank Redemption', 1994, '1994-10-14');

# %% [markdown]
# ## 以 `ALTER TABLE` 更新資料表
#
# - 以 `ADD` 新增欄位。
# - 以 `DROP` 刪除欄位。
# - 以 `RENAME` 重新命名欄位。
# - 以 `MODIFY` 修改欄位資料類型。

# %% [markdown]
# ## 新增欄位
#
# ```sql
# ALTER TABLE database_name.table_name ADD column_name datatype;
# ```

# %%
DROP TABLE IF EXISTS cloned_imdb.movies;

# %%
CREATE TABLE cloned_imdb.movies (
    id int unsigned
);

# %%
ALTER TABLE cloned_imdb.movies ADD title varchar(200);

# %%
SELECT *
  FROM cloned_imdb.movies;
# Out:
# Empty set (0.00 sec)

# %% [markdown]
# ## 刪除欄位
#
# ```sql
# ALTER TABLE database_name.table_name DROP column_name;
# ```

# %%
ALTER TABLE cloned_imdb.movies DROP title;

# %%
SELECT *
  FROM cloned_imdb.movies;
# Out:
# Empty set (0.00 sec)

# %% [markdown]
# ## 重新命名欄位
#
# ```sql
# ALTER TABLE database_name.table_name RENAME COLUMN column_name TO new_column_name;
# ```

# %%
ALTER TABLE cloned_imdb.movies RENAME COLUMN id TO movie_id;

# %%
SELECT *
  FROM cloned_imdb.movies;
# Out:
# Empty set (0.00 sec)

# %% [markdown]
# ## 修改欄位資料類型
#
# ```sql
# ALTER TABLE database_name.table_name MODIFY COLUMN column_name new_datatype;
# ```

# %%
ALTER TABLE cloned_imdb.movies MODIFY COLUMN movie_id tinyint unsigned;

# %%
SHOW FIELDS FROM cloned_imdb.movies
           WHERE Field ='movie_id';
# Out:
# +----------+------------------+------+-----+---------+-------+
# | Field    | Type             | Null | Key | Default | Extra |
# +----------+------------------+------+-----+---------+-------+
# | movie_id | tinyint unsigned | YES  |     | NULL    |       |
# +----------+------------------+------+-----+---------+-------+
# 1 row in set (0.00 sec)

# %% [markdown]
# ## 以 `TRUNCATE` 刪除資料表中的所有資料
#
# ```sql
# TRUNCATE TABLE database_name.table_name;
# ```

# %%
DROP TABLE IF EXISTS cloned_imdb.movies;

# %%
CREATE TABLE cloned_imdb.movies (
    id int unsigned
);

# %%
INSERT INTO cloned_imdb.movies (id)
VALUES (1);

# %%
TRUNCATE TABLE cloned_imdb.movies;

# %%
SELECT *
  FROM cloned_imdb.movies;
# Out:
# Empty set (0.00 sec)

# %% [markdown]
# ## 以 `DROP TABLE` 刪除資料表
#
# ```sql
# DROP TABLE IF EXISTS database_name.table_name;
# ```

# %%
DROP TABLE IF EXISTS cloned_imdb.movies;

# %% [markdown]
# ```sql
# SELECT *
#   FROM cloned_imdb.movies;
# ```

# %% [markdown]
# ## 連線工具的使用者介面也可以輕鬆刪除資料表
#
# 左側資料庫按右鍵下拉式選單點選 Delete

# %% [markdown]
# ## 檢視表（View）

# %% [markdown]
# ## 什麼是檢視表
#
# - 檢視表是一段被儲存在資料庫中的 SQL 敘述，具有一個物件命名。
# - 想要檢視該段 SQL 敘述的查詢結果時，只需要將檢視表命名放在 `FROM` 保留字之後即可。

# %% [markdown]
# ## 檢視表不等於資料表
#
# - 實際上檢視表儲存的內容並不是列（Rows）與欄（Columns）所組成的二維表格，而是一段 SQL 敘述。
# - 只有在對檢視表寫作資料查詢語言時，才會執行被儲存的 SQL 敘述。
# - 簡單來說，檢視表是一種介於「子查詢」與「創造資料表」之間的功能。
# - 檢視表就像是資料表版本的「衍生計算欄位」，由於多數「非資料庫管理員」的資料分析師在公司中沒有創造資料表的權限，因此若是有創造檢視表的權限將可以滿足我們對資料表的創造需求。

# %% [markdown]
# ## 以 `CREATE VIEW` 創造檢視表
#
# ```sql
# CREATE VIEW database_name.view_name
#     AS
#    SQL statement to be stored;
# ```

# %%
CREATE VIEW imdb.avg_rating_by_release_year
    AS
SELECT release_year,
       AVG(rating) AS avg_rating
  FROM imdb.movies
 GROUP BY release_year;

# %% [markdown]
# ## 將檢視表命名放在 `FROM` 保留字之後來使用

# %%
SELECT *
  FROM imdb.avg_rating_by_release_year
 WHERE avg_rating >= 8.7;
# Out:
# +--------------+------------+
# | release_year | avg_rating |
# +--------------+------------+
# | 1994         | 8.8        |
# +--------------+------------+
# | 1972         | 9.2        |
# +--------------+------------+
# | 2023         | 8.85       |
# +--------------+------------+
# 3 rows in set (0.00 sec)

# %% [markdown]
# ## 以 `DROP VIEW` 刪除檢視表
#
# ```sql
# DROP VIEW IF EXISTS database_name.view_name;
# ```

# %% [markdown]
# ## 刪除檢視表之後，就無法在 `FROM` 保留字之後指定檢視表作為資料來源
#
# ```
# Table 'imdb.avg_rating_by_release_year' doesn't exist
# ```

# %% [markdown]
# ```sql
# DROP VIEW IF EXISTS imdb.avg_rating_by_release_year;
# SELECT *
#   FROM imdb.avg_rating_by_release_year
#  WHERE avg_rating >= 8.5;
# ```

# %% [markdown]
# ## 連線工具的使用者介面也可以輕鬆刪除檢視表
#
# 左側資料庫按右鍵下拉式選單點選 Delete

# %% [markdown]
# ## 透過檢視表複習 MySQL 不同的連接類型
#
# - `JOIN` 保留兩個資料表的「交集」觀測值。
# - `LEFT JOIN` 保留左資料表（接在 `FROM` 之後）的所有觀測值。
# - `RIGHT JOIN` 保留右資料表（接在 `JOIN` 之後）的所有觀測值。

# %% [markdown]
# ## 建立一個左檢視表 `casting_shawshank_darkknight`

# %%
CREATE VIEW imdb.casting_shawshank_darkknight
    AS
SELECT *
  FROM imdb.movies_actors
 WHERE movie_id IN (1, 3);

# %% [markdown]
# ## 建立一個右檢視表 `movies_shawshank_forrest`

# %%
CREATE VIEW imdb.movies_shawshank_forrest
    AS
SELECT *
  FROM imdb.movies
 WHERE title IN ('The Shawshank Redemption', 'Forrest Gump');

# %% [markdown]
# ## `JOIN` 保留兩個資料表的「交集」觀測值

# %%
SELECT movies_shawshank_forrest.title,
       casting_shawshank_darkknight.actor_id
  FROM imdb.casting_shawshank_darkknight
  JOIN imdb.movies_shawshank_forrest
    ON casting_shawshank_darkknight.movie_id = movies_shawshank_forrest.id;
# Out:
# +--------------------------+----------+
# | title                    | actor_id |
# +--------------------------+----------+
# | The Shawshank Redemption | 15237    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11321    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1673     |
# +--------------------------+----------+
# | The Shawshank Redemption | 16177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2758     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5408     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10334    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6901     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7232     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9235     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11514    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1882     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3465     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8249     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8367     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12146    |
# +--------------------------+----------+
# | The Shawshank Redemption | 12866    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14043    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5548     |
# +--------------------------+----------+
# | The Shawshank Redemption | 444      |
# +--------------------------+----------+
# | The Shawshank Redemption | 15854    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7810     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4898     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9943     |
# +--------------------------+----------+
# | The Shawshank Redemption | 286      |
# +--------------------------+----------+
# | The Shawshank Redemption | 11324    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2918     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5141     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11522    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11499    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7652     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5888     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3891     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3951     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13244    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3106     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7792     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8828     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4572     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1505     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13474    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7963     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2720     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3774     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2757     |
# +--------------------------+----------+
# | The Shawshank Redemption | 6825     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13431    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2442     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13139    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1848     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12132    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6751     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3627     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4992     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12948    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13875    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14219    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13112    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3395     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1759     |
# +--------------------------+----------+
# | The Shawshank Redemption | 546      |
# +--------------------------+----------+
# | The Shawshank Redemption | 5138     |
# +--------------------------+----------+
# | The Shawshank Redemption | 14177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 10928    |
# +--------------------------+----------+
# | The Shawshank Redemption | 15562    |
# +--------------------------+----------+
# | The Shawshank Redemption | 5275     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2702     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11520    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1766     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7582     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10279    |
# +--------------------------+----------+
# 74 rows in set (0.01 sec)

# %% [markdown]
# ## `LEFT JOIN` 保留左資料表的所有觀測值

# %%
SELECT movies_shawshank_forrest.title,
       casting_shawshank_darkknight.actor_id
  FROM imdb.casting_shawshank_darkknight
  LEFT JOIN imdb.movies_shawshank_forrest
    ON casting_shawshank_darkknight.movie_id = movies_shawshank_forrest.id;
# Out:
# +--------------------------+----------+
# | title                    | actor_id |
# +--------------------------+----------+
# | The Shawshank Redemption | 15237    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11321    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1673     |
# +--------------------------+----------+
# | The Shawshank Redemption | 16177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2758     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5408     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10334    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6901     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7232     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9235     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11514    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1882     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3465     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8249     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8367     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12146    |
# +--------------------------+----------+
# | The Shawshank Redemption | 12866    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14043    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5548     |
# +--------------------------+----------+
# | The Shawshank Redemption | 444      |
# +--------------------------+----------+
# | The Shawshank Redemption | 15854    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7810     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4898     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9943     |
# +--------------------------+----------+
# | The Shawshank Redemption | 286      |
# +--------------------------+----------+
# | The Shawshank Redemption | 11324    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2918     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5141     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11522    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11499    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7652     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5888     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3891     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3951     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13244    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3106     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7792     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8828     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4572     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1505     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13474    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7963     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2720     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3774     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2757     |
# +--------------------------+----------+
# | The Shawshank Redemption | 6825     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13431    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2442     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13139    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1848     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12132    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6751     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3627     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4992     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12948    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13875    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14219    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13112    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3395     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1759     |
# +--------------------------+----------+
# | The Shawshank Redemption | 546      |
# +--------------------------+----------+
# | The Shawshank Redemption | 5138     |
# +--------------------------+----------+
# | The Shawshank Redemption | 14177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 10928    |
# +--------------------------+----------+
# | The Shawshank Redemption | 15562    |
# +--------------------------+----------+
# | The Shawshank Redemption | 5275     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2702     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11520    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1766     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7582     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10279    |
# +--------------------------+----------+
# | NULL                     | 2612     |
# +--------------------------+----------+
# | NULL                     | 6037     |
# +--------------------------+----------+
# | NULL                     | 17       |
# +--------------------------+----------+
# | NULL                     | 10827    |
# +--------------------------+----------+
# | NULL                     | 9978     |
# +--------------------------+----------+
# | NULL                     | 5145     |
# +--------------------------+----------+
# | NULL                     | 11321    |
# +--------------------------+----------+
# | NULL                     | 11299    |
# +--------------------------+----------+
# | NULL                     | 13465    |
# +--------------------------+----------+
# | NULL                     | 2742     |
# +--------------------------+----------+
# | NULL                     | 2508     |
# +--------------------------+----------+
# | NULL                     | 11543    |
# +--------------------------+----------+
# | NULL                     | 4455     |
# +--------------------------+----------+
# | NULL                     | 13118    |
# +--------------------------+----------+
# | NULL                     | 912      |
# +--------------------------+----------+
# | NULL                     | 8777     |
# +--------------------------+----------+
# | NULL                     | 2858     |
# +--------------------------+----------+
# | NULL                     | 8303     |
# +--------------------------+----------+
# | NULL                     | 10744    |
# +--------------------------+----------+
# | NULL                     | 11475    |
# +--------------------------+----------+
# | NULL                     | 11007    |
# +--------------------------+----------+
# | NULL                     | 10998    |
# +--------------------------+----------+
# | NULL                     | 16184    |
# +--------------------------+----------+
# | NULL                     | 3214     |
# +--------------------------+----------+
# | NULL                     | 10896    |
# +--------------------------+----------+
# | NULL                     | 10621    |
# +--------------------------+----------+
# | NULL                     | 16127    |
# +--------------------------+----------+
# | NULL                     | 11835    |
# +--------------------------+----------+
# | NULL                     | 5615     |
# +--------------------------+----------+
# | NULL                     | 4484     |
# +--------------------------+----------+
# | NULL                     | 1293     |
# +--------------------------+----------+
# | NULL                     | 15873    |
# +--------------------------+----------+
# | NULL                     | 4130     |
# +--------------------------+----------+
# | NULL                     | 11761    |
# +--------------------------+----------+
# | NULL                     | 748      |
# +--------------------------+----------+
# | NULL                     | 6792     |
# +--------------------------+----------+
# | NULL                     | 15364    |
# +--------------------------+----------+
# | NULL                     | 16092    |
# +--------------------------+----------+
# | NULL                     | 6794     |
# +--------------------------+----------+
# | NULL                     | 12017    |
# +--------------------------+----------+
# | NULL                     | 13829    |
# +--------------------------+----------+
# | NULL                     | 7275     |
# +--------------------------+----------+
# | NULL                     | 12003    |
# +--------------------------+----------+
# | NULL                     | 13967    |
# +--------------------------+----------+
# | NULL                     | 2424     |
# +--------------------------+----------+
# | NULL                     | 16215    |
# +--------------------------+----------+
# | NULL                     | 3368     |
# +--------------------------+----------+
# | NULL                     | 14517    |
# +--------------------------+----------+
# | NULL                     | 8765     |
# +--------------------------+----------+
# | NULL                     | 7593     |
# +--------------------------+----------+
# | NULL                     | 12945    |
# +--------------------------+----------+
# | NULL                     | 3287     |
# +--------------------------+----------+
# | NULL                     | 2582     |
# +--------------------------+----------+
# | NULL                     | 177      |
# +--------------------------+----------+
# | NULL                     | 12444    |
# +--------------------------+----------+
# | NULL                     | 12061    |
# +--------------------------+----------+
# | NULL                     | 15978    |
# +--------------------------+----------+
# | NULL                     | 15862    |
# +--------------------------+----------+
# | NULL                     | 11416    |
# +--------------------------+----------+
# | NULL                     | 8519     |
# +--------------------------+----------+
# | NULL                     | 10585    |
# +--------------------------+----------+
# | NULL                     | 10798    |
# +--------------------------+----------+
# | NULL                     | 9227     |
# +--------------------------+----------+
# | NULL                     | 12313    |
# +--------------------------+----------+
# | NULL                     | 10582    |
# +--------------------------+----------+
# | NULL                     | 677      |
# +--------------------------+----------+
# | NULL                     | 1011     |
# +--------------------------+----------+
# | NULL                     | 3960     |
# +--------------------------+----------+
# | NULL                     | 6094     |
# +--------------------------+----------+
# | NULL                     | 15426    |
# +--------------------------+----------+
# | NULL                     | 2949     |
# +--------------------------+----------+
# | NULL                     | 14826    |
# +--------------------------+----------+
# | NULL                     | 9653     |
# +--------------------------+----------+
# | NULL                     | 12296    |
# +--------------------------+----------+
# | NULL                     | 8308     |
# +--------------------------+----------+
# | NULL                     | 3052     |
# +--------------------------+----------+
# | NULL                     | 10613    |
# +--------------------------+----------+
# | NULL                     | 15352    |
# +--------------------------+----------+
# | NULL                     | 15134    |
# +--------------------------+----------+
# | NULL                     | 16101    |
# +--------------------------+----------+
# | NULL                     | 88       |
# +--------------------------+----------+
# | NULL                     | 15598    |
# +--------------------------+----------+
# | NULL                     | 1932     |
# +--------------------------+----------+
# | NULL                     | 3324     |
# +--------------------------+----------+
# | NULL                     | 5382     |
# +--------------------------+----------+
# | NULL                     | 8139     |
# +--------------------------+----------+
# | NULL                     | 6873     |
# +--------------------------+----------+
# | NULL                     | 11632    |
# +--------------------------+----------+
# | NULL                     | 6335     |
# +--------------------------+----------+
# | NULL                     | 9276     |
# +--------------------------+----------+
# | NULL                     | 5589     |
# +--------------------------+----------+
# | NULL                     | 13422    |
# +--------------------------+----------+
# | NULL                     | 13496    |
# +--------------------------+----------+
# | NULL                     | 15946    |
# +--------------------------+----------+
# | NULL                     | 10838    |
# +--------------------------+----------+
# | NULL                     | 5836     |
# +--------------------------+----------+
# | NULL                     | 1789     |
# +--------------------------+----------+
# | NULL                     | 7195     |
# +--------------------------+----------+
# | NULL                     | 15560    |
# +--------------------------+----------+
# | NULL                     | 10632    |
# +--------------------------+----------+
# | NULL                     | 14609    |
# +--------------------------+----------+
# | NULL                     | 492      |
# +--------------------------+----------+
# | NULL                     | 11094    |
# +--------------------------+----------+
# | NULL                     | 16013    |
# +--------------------------+----------+
# | NULL                     | 10396    |
# +--------------------------+----------+
# | NULL                     | 15423    |
# +--------------------------+----------+
# | NULL                     | 12056    |
# +--------------------------+----------+
# | NULL                     | 1644     |
# +--------------------------+----------+
# | NULL                     | 2615     |
# +--------------------------+----------+
# | NULL                     | 2940     |
# +--------------------------+----------+
# | NULL                     | 8094     |
# +--------------------------+----------+
# | NULL                     | 3974     |
# +--------------------------+----------+
# | NULL                     | 3553     |
# +--------------------------+----------+
# | NULL                     | 9866     |
# +--------------------------+----------+
# | NULL                     | 10273    |
# +--------------------------+----------+
# | NULL                     | 14346    |
# +--------------------------+----------+
# | NULL                     | 4651     |
# +--------------------------+----------+
# | NULL                     | 3352     |
# +--------------------------+----------+
# | NULL                     | 8272     |
# +--------------------------+----------+
# | NULL                     | 9282     |
# +--------------------------+----------+
# | NULL                     | 6910     |
# +--------------------------+----------+
# | NULL                     | 10561    |
# +--------------------------+----------+
# | NULL                     | 6131     |
# +--------------------------+----------+
# | NULL                     | 8784     |
# +--------------------------+----------+
# | NULL                     | 6953     |
# +--------------------------+----------+
# | NULL                     | 3361     |
# +--------------------------+----------+
# | NULL                     | 12593    |
# +--------------------------+----------+
# | NULL                     | 1943     |
# +--------------------------+----------+
# | NULL                     | 3198     |
# +--------------------------+----------+
# | NULL                     | 12947    |
# +--------------------------+----------+
# | NULL                     | 15478    |
# +--------------------------+----------+
# | NULL                     | 7389     |
# +--------------------------+----------+
# | NULL                     | 9194     |
# +--------------------------+----------+
# | NULL                     | 12582    |
# +--------------------------+----------+
# | NULL                     | 3504     |
# +--------------------------+----------+
# | NULL                     | 3081     |
# +--------------------------+----------+
# | NULL                     | 5186     |
# +--------------------------+----------+
# | NULL                     | 12827    |
# +--------------------------+----------+
# | NULL                     | 7031     |
# +--------------------------+----------+
# | NULL                     | 7032     |
# +--------------------------+----------+
# | NULL                     | 3271     |
# +--------------------------+----------+
# | NULL                     | 3383     |
# +--------------------------+----------+
# | NULL                     | 14035    |
# +--------------------------+----------+
# | NULL                     | 10269    |
# +--------------------------+----------+
# | NULL                     | 15217    |
# +--------------------------+----------+
# | NULL                     | 3083     |
# +--------------------------+----------+
# | NULL                     | 9650     |
# +--------------------------+----------+
# | NULL                     | 14255    |
# +--------------------------+----------+
# | NULL                     | 11456    |
# +--------------------------+----------+
# | NULL                     | 15139    |
# +--------------------------+----------+
# | NULL                     | 2554     |
# +--------------------------+----------+
# | NULL                     | 399      |
# +--------------------------+----------+
# | NULL                     | 9633     |
# +--------------------------+----------+
# | NULL                     | 10883    |
# +--------------------------+----------+
# | NULL                     | 8178     |
# +--------------------------+----------+
# | NULL                     | 8925     |
# +--------------------------+----------+
# | NULL                     | 7862     |
# +--------------------------+----------+
# | NULL                     | 14089    |
# +--------------------------+----------+
# | NULL                     | 1527     |
# +--------------------------+----------+
# | NULL                     | 14868    |
# +--------------------------+----------+
# | NULL                     | 2383     |
# +--------------------------+----------+
# | NULL                     | 4536     |
# +--------------------------+----------+
# | NULL                     | 3150     |
# +--------------------------+----------+
# | NULL                     | 12696    |
# +--------------------------+----------+
# | NULL                     | 16085    |
# +--------------------------+----------+
# | NULL                     | 1678     |
# +--------------------------+----------+
# | NULL                     | 11604    |
# +--------------------------+----------+
# | NULL                     | 10316    |
# +--------------------------+----------+
# | NULL                     | 2443     |
# +--------------------------+----------+
# | NULL                     | 15147    |
# +--------------------------+----------+
# | NULL                     | 3853     |
# +--------------------------+----------+
# | NULL                     | 13696    |
# +--------------------------+----------+
# | NULL                     | 15223    |
# +--------------------------+----------+
# | NULL                     | 10919    |
# +--------------------------+----------+
# | NULL                     | 3090     |
# +--------------------------+----------+
# | NULL                     | 8227     |
# +--------------------------+----------+
# | NULL                     | 3913     |
# +--------------------------+----------+
# | NULL                     | 3428     |
# +--------------------------+----------+
# | NULL                     | 6463     |
# +--------------------------+----------+
# | NULL                     | 3568     |
# +--------------------------+----------+
# | NULL                     | 11702    |
# +--------------------------+----------+
# | NULL                     | 8131     |
# +--------------------------+----------+
# | NULL                     | 239      |
# +--------------------------+----------+
# | NULL                     | 6508     |
# +--------------------------+----------+
# | NULL                     | 8232     |
# +--------------------------+----------+
# | NULL                     | 15360    |
# +--------------------------+----------+
# | NULL                     | 9106     |
# +--------------------------+----------+
# | NULL                     | 13700    |
# +--------------------------+----------+
# | NULL                     | 6840     |
# +--------------------------+----------+
# | NULL                     | 3619     |
# +--------------------------+----------+
# | NULL                     | 3407     |
# +--------------------------+----------+
# | NULL                     | 8240     |
# +--------------------------+----------+
# | NULL                     | 8243     |
# +--------------------------+----------+
# | NULL                     | 13793    |
# +--------------------------+----------+
# | NULL                     | 2703     |
# +--------------------------+----------+
# | NULL                     | 9573     |
# +--------------------------+----------+
# | NULL                     | 5631     |
# +--------------------------+----------+
# | NULL                     | 4510     |
# +--------------------------+----------+
# | NULL                     | 8941     |
# +--------------------------+----------+
# | NULL                     | 13513    |
# +--------------------------+----------+
# | NULL                     | 12248    |
# +--------------------------+----------+
# | NULL                     | 2408     |
# +--------------------------+----------+
# | NULL                     | 10084    |
# +--------------------------+----------+
# | NULL                     | 2047     |
# +--------------------------+----------+
# | NULL                     | 13956    |
# +--------------------------+----------+
# | NULL                     | 12379    |
# +--------------------------+----------+
# | NULL                     | 5153     |
# +--------------------------+----------+
# | NULL                     | 8795     |
# +--------------------------+----------+
# | NULL                     | 4269     |
# +--------------------------+----------+
# | NULL                     | 5635     |
# +--------------------------+----------+
# | NULL                     | 6945     |
# +--------------------------+----------+
# | NULL                     | 613      |
# +--------------------------+----------+
# | NULL                     | 15907    |
# +--------------------------+----------+
# | NULL                     | 10991    |
# +--------------------------+----------+
# | NULL                     | 11054    |
# +--------------------------+----------+
# | NULL                     | 15272    |
# +--------------------------+----------+
# | NULL                     | 9067     |
# +--------------------------+----------+
# | NULL                     | 14483    |
# +--------------------------+----------+
# | NULL                     | 7992     |
# +--------------------------+----------+
# | NULL                     | 9709     |
# +--------------------------+----------+
# | NULL                     | 4026     |
# +--------------------------+----------+
# | NULL                     | 1974     |
# +--------------------------+----------+
# | NULL                     | 6998     |
# +--------------------------+----------+
# | NULL                     | 13293    |
# +--------------------------+----------+
# | NULL                     | 8174     |
# +--------------------------+----------+
# | NULL                     | 13315    |
# +--------------------------+----------+
# | NULL                     | 13039    |
# +--------------------------+----------+
# | NULL                     | 312      |
# +--------------------------+----------+
# | NULL                     | 7473     |
# +--------------------------+----------+
# | NULL                     | 2545     |
# +--------------------------+----------+
# | NULL                     | 8008     |
# +--------------------------+----------+
# | NULL                     | 15273    |
# +--------------------------+----------+
# | NULL                     | 15397    |
# +--------------------------+----------+
# | NULL                     | 2733     |
# +--------------------------+----------+
# | NULL                     | 8014     |
# +--------------------------+----------+
# | NULL                     | 6894     |
# +--------------------------+----------+
# | NULL                     | 8028     |
# +--------------------------+----------+
# | NULL                     | 7697     |
# +--------------------------+----------+
# | NULL                     | 11147    |
# +--------------------------+----------+
# | NULL                     | 2605     |
# +--------------------------+----------+
# | NULL                     | 9660     |
# +--------------------------+----------+
# | NULL                     | 3562     |
# +--------------------------+----------+
# | NULL                     | 4546     |
# +--------------------------+----------+
# | NULL                     | 8955     |
# +--------------------------+----------+
# 318 rows in set (0.01 sec)

# %% [markdown]
# ## `RIGHT JOIN` 保留右資料表的所有觀測值

# %%
SELECT movies_shawshank_forrest.title,
       casting_shawshank_darkknight.actor_id
  FROM imdb.casting_shawshank_darkknight
 RIGHT JOIN imdb.movies_shawshank_forrest
    ON casting_shawshank_darkknight.movie_id = movies_shawshank_forrest.id;
# Out:
# +--------------------------+----------+
# | title                    | actor_id |
# +--------------------------+----------+
# | The Shawshank Redemption | 15237    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11321    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1673     |
# +--------------------------+----------+
# | The Shawshank Redemption | 16177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2758     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5408     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10334    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6901     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7232     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9235     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11514    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1882     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3465     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8249     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8367     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12146    |
# +--------------------------+----------+
# | The Shawshank Redemption | 12866    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14043    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5548     |
# +--------------------------+----------+
# | The Shawshank Redemption | 444      |
# +--------------------------+----------+
# | The Shawshank Redemption | 15854    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7810     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4898     |
# +--------------------------+----------+
# | The Shawshank Redemption | 9943     |
# +--------------------------+----------+
# | The Shawshank Redemption | 286      |
# +--------------------------+----------+
# | The Shawshank Redemption | 11324    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2918     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5141     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11522    |
# +--------------------------+----------+
# | The Shawshank Redemption | 11499    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7652     |
# +--------------------------+----------+
# | The Shawshank Redemption | 5888     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3859     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3891     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3951     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13244    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3106     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7792     |
# +--------------------------+----------+
# | The Shawshank Redemption | 8828     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4572     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1505     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13474    |
# +--------------------------+----------+
# | The Shawshank Redemption | 7963     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2720     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3774     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2757     |
# +--------------------------+----------+
# | The Shawshank Redemption | 6825     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13431    |
# +--------------------------+----------+
# | The Shawshank Redemption | 2442     |
# +--------------------------+----------+
# | The Shawshank Redemption | 13139    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1848     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12132    |
# +--------------------------+----------+
# | The Shawshank Redemption | 6751     |
# +--------------------------+----------+
# | The Shawshank Redemption | 3627     |
# +--------------------------+----------+
# | The Shawshank Redemption | 4992     |
# +--------------------------+----------+
# | The Shawshank Redemption | 12948    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13875    |
# +--------------------------+----------+
# | The Shawshank Redemption | 14219    |
# +--------------------------+----------+
# | The Shawshank Redemption | 13112    |
# +--------------------------+----------+
# | The Shawshank Redemption | 3395     |
# +--------------------------+----------+
# | The Shawshank Redemption | 1759     |
# +--------------------------+----------+
# | The Shawshank Redemption | 546      |
# +--------------------------+----------+
# | The Shawshank Redemption | 5138     |
# +--------------------------+----------+
# | The Shawshank Redemption | 14177    |
# +--------------------------+----------+
# | The Shawshank Redemption | 10928    |
# +--------------------------+----------+
# | The Shawshank Redemption | 15562    |
# +--------------------------+----------+
# | The Shawshank Redemption | 5275     |
# +--------------------------+----------+
# | The Shawshank Redemption | 2702     |
# +--------------------------+----------+
# | The Shawshank Redemption | 11520    |
# +--------------------------+----------+
# | The Shawshank Redemption | 1766     |
# +--------------------------+----------+
# | The Shawshank Redemption | 7582     |
# +--------------------------+----------+
# | The Shawshank Redemption | 10279    |
# +--------------------------+----------+
# | Forrest Gump             | NULL     |
# +--------------------------+----------+
# 75 rows in set (0.00 sec)

# %% [markdown]
# ## 角色（Role）與使用者（User）的創造
#
# 與資料控制語言（Data Control Language, DCL）相關，現在先略過不提。

# %% [markdown]
# ## 重點整理
#
# - 資料定義語言主要的保留字：
#     - `CREATE`
#     - `TRUNCATE`
#     - `DROP`
#     - `ALTER`

# %% [markdown]
# ## 重點整理（續）
#
# - 哪些資料庫管理系統中的物件可以被創造、刪除與更新：
#     - 資料庫（Database）。
#     - 資料表（Table）。
#     - 檢視表（View）。
#     - 角色（Role）與使用者（User）。

# %% [markdown]
# ## 重點整理（續）
#
# - MySQL 的資料類型
#     - 整數。
#     - 浮點數。
#     - 文字。
#     - 日期與時間。

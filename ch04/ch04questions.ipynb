# %% [markdown]
# # 進階的 SQL 五十道練習
#
# > 資料定義語言
#
# [數聚點](https://www.datainpoint.com) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 仔細閱讀題目敘述並且在自己的電腦透過 DBeaver 完成。
# - 下載批改測試檔案並放置在自己熟悉的目錄（資料夾）之中。
#     - 批改測試檔案：[ch04-test-ddl.py](https://classroom-hahow-sqlfiftyplus.s3.ap-northeast-1.amazonaws.com/test_scripts/ch04-test-ddl.py)
# - 執行測試：
#     - 開啟 Anaconda Prompt（Windows 作業系統）或 Terminal（macOS）
#     - 啟動專案環境 `conda activate pythonmysql`
#     - 透過 `cd` 指令移動到放置批改測試檔案的目錄（資料夾）。
#     - 執行 `python ch04-test-ddl.py root {roots_password}`
# - 終端機操作的技巧：
#     - 在終端機畫面中按「向上箭頭」可以叫出先前執行過的指令。
#     - Windows 作業系統可以使用 `cls` 指令清空 Anaconda Prompt 畫面；macOS 可以使用 `clear` 指令或 `Ctrl - L` 清空 Terminal 畫面。

# %% [markdown]
# ## 0401 在本機的 MySQL Server 建立 `cloned_covid19` 資料庫，charset 指定 utf8mb4，collation 指定 utf8mb4_unicode_ci
#
# |Database|
# |--------|
# |cloned_covid19|
# |cloned_imdb|
# |covid19|
# |imdb|
# |information_schema|
# |mysql|
# |performance_schema|
# |sys|

# %% [markdown]
# ## 0402 承接 0401，在 `cloned_covid19` 資料庫中，建立 `locations` 資料表，欄位名稱與資料類型如下所示（不需輸入任何資料）。
#
# ```
# id int unsigned,
# country_name VARCHAR(200),
# iso2 CHAR(2),
# iso3 CHAR(3),
# longitude float,
# latitude float
# ```

# %% [markdown]
# ## 0403 承接 0401，在 `cloned_covid19` 資料庫中，建立 `calendars` 資料表，欄位名稱與資料類型如下所示（不需輸入任何資料）。
#
# ```
# id int unsigned,
# recorded_on date
# ```

# %% [markdown]
# ## 0404 承接 0401，在 `cloned_covid19` 資料庫中，建立 `accumulative_cases` 資料表，欄位名稱與資料類型如下所示（不需輸入任何資料）。
#
# ```
# id int unsigned,
# calendar_id int unsigned,
# location_id int unsigned,
# confirmed bigint,
# deaths bigint
# ```

# %% [markdown]
# ## 0405 在 `covid19` 資料庫中，篩選 `accumulative_cases.calendar_id = 1164` 建立 `accumulative_cases_20230309` 檢視表，檢視表資料內容如下所示。
#
# |id|calendar_id|location_id|confirmed|deaths|
# |--|-----------|-----------|---------|------|
# |1143|1164|1|209451|7896|
# |2286|1164|2|334457|3598|
# |3429|1164|3|271496|6881|
# |4572|1164|4|47890|165|
# |5715|1164|5|105288|1933|
# |6858|1164|6|11|0|
# |8001|1164|7|9106|146|
# |9144|1164|8|10044957|130472|
# |10287|1164|9|447308|8727|
# |11430|1164|10|232974|228|
# |12573|1164|11|3915992|6529|
# |13716|1164|13|105111|91|
# |14859|1164|14|1800236|2783|
# |16002|1164|15|883620|1365|
# |17145|1164|16|287507|256|
# |18288|1164|17|2880559|7370|
# |19431|1164|18|1293461|952|
# |325755|1164|953|11945|2159|
# |326898|1164|954|343135|4057|
# |328041|1164|955|264276|5671|

# %% [markdown]
# ## 0406 在 `covid19` 資料庫中，篩選 `locations.iso3 IN ('TWN', 'JPN')` 建立 `locations_twn_jpn` 檢視表，檢視表資料內容如下所示。
#
# |id|country_name|province_name|iso2|iso3|latitude|longitude|population|
# |--|------------|-------------|----|----|--------|---------|----------|
# |319|Japan|Aichi|JP|JPN|35.0355|137.212|7552239|
# |320|Japan|Akita|JP|JPN|39.7487|140.408|966490|
# |321|Japan|Aomori|JP|JPN|40.7815|140.829|1246371|
# |322|Japan|Chiba|JP|JPN|35.5101|140.199|6259382|
# |323|Japan|Ehime|JP|JPN|33.6248|132.857|1339215|
# |324|Japan|Fukui|JP|JPN|35.8466|136.225|767937|
# |325|Japan|Fukuoka|JP|JPN|33.526|130.667|5103679|
# |326|Japan|Fukushima|JP|JPN|37.3789|140.223|1845519|
# |327|Japan|Gifu|JP|JPN|35.7787|137.056|1986587|
# |328|Japan|Gunma|JP|JPN|36.5045|138.986|1942456|
# |329|Japan|Hiroshima|JP|JPN|34.6053|132.789|2804177|
# |330|Japan|Hokkaido|JP|JPN|43.3857|142.552|5250049|
# |331|Japan|Hyogo|JP|JPN|35.0399|134.828|5466190|
# |332|Japan|Ibaraki|JP|JPN|36.3036|140.32|2860307|
# |333|Japan|Ishikawa|JP|JPN|36.7695|136.771|1137649|
# |334|Japan|Iwate|JP|JPN|39.5933|141.362|1226816|
# |335|Japan|Kagawa|JP|JPN|34.2173|133.969|956347|
# |336|Japan|Kagoshima|JP|JPN|31.0095|130.431|1602273|
# |337|Japan|Kanagawa|JP|JPN|35.4153|139.339|9198268|
# |338|Japan|Kochi|JP|JPN|33.4225|133.367|698029|
# |339|Japan|Kumamoto|JP|JPN|32.6082|130.745|1747567|
# |340|Japan|Kyoto|JP|JPN|35.2538|135.443|2582957|
# |341|Japan|Mie|JP|JPN|34.508|136.376|1780882|
# |342|Japan|Miyagi|JP|JPN|38.4469|140.927|2306365|
# |343|Japan|Miyazaki|JP|JPN|32.1932|131.299|1073301|
# |344|Japan|Nagano|JP|JPN|36.1321|138.046|2048790|
# |345|Japan|Nagasaki|JP|JPN|33.2357|129.608|1326524|
# |346|Japan|Nara|JP|JPN|34.3175|135.872|1330123|
# |347|Japan|Niigata|JP|JPN|37.5218|138.919|2223106|
# |348|Japan||JP|JPN|36.2048|138.253|126476458|
# |349|Japan|Oita|JP|JPN|33.2007|131.433|1135434|
# |350|Japan|Okayama|JP|JPN|34.8925|133.826|1889586|
# |351|Japan|Okinawa|JP|JPN|25.7689|126.668|1453168|
# |352|Japan|Osaka|JP|JPN|34.621|135.507|8809363|
# |353|Japan|Port Quarantine|JP|JPN|||0|
# |354|Japan|Saga|JP|JPN|33.287|130.116|814711|
# |355|Japan|Saitama|JP|JPN|35.9971|139.348|7349693|
# |356|Japan|Shiga|JP|JPN|35.2158|136.138|1413943|
# |357|Japan|Shimane|JP|JPN|35.0708|132.554|674346|
# |358|Japan|Shizuoka|JP|JPN|34.917|138.408|3643528|
# |359|Japan|Tochigi|JP|JPN|36.6899|139.819|1933990|
# |360|Japan|Tokushima|JP|JPN|33.9192|134.242|727977|
# |361|Japan|Tokyo|JP|JPN|35.7113|139.447|13920663|
# |362|Japan|Tottori|JP|JPN|35.3591|133.864|555558|
# |363|Japan|Toyama|JP|JPN|36.6375|137.269|1043502|
# |364|Japan|Wakayama|JP|JPN|33.9119|135.505|924933|
# |365|Japan|Yamagata|JP|JPN|38.4484|140.102|1077666|
# |366|Japan|Yamaguchi|JP|JPN|34.2012|131.573|1358336|
# |367|Japan|Yamanashi|JP|JPN|35.6124|138.611|810956|
# |822|Taiwan||TW|TWN|23.7|121.0|23816775|

# %% [markdown]
# ## 0407 承接 0405 與 0406 在 `covid19` 資料庫中，建立 `views_joined` 檢視表，使用 `JOIN` 連接兩個檢視表，以 `accumulative_cases_20230309` 作為左檢視表、`locations_twn_jpn` 作為右檢視表，連接後的檢視表內容如下所示。
#
# |country_name|province_name|confirmed|deaths|
# |------------|-------------|---------|------|
# |Japan||33320438|72997|
# |Taiwan||9970937|17672|

# %% [markdown]
# ## 0408 承接 0405 與 0406 在 `covid19` 資料庫中，建立 `views_left_joined` 檢視表，使用 `LEFT JOIN` 連接兩個檢視表，以 `accumulative_cases_20230309` 作為左檢視表、`locations_twn_jpn` 作為右檢視表，連接後的檢視表內容如下所示。
#
# |country_name|province_name|confirmed|deaths|
# |------------|-------------|---------|------|
# |Taiwan||9970937|17672|
# |Japan||33320438|72997|
# |||209451|7896|
# |||334457|3598|
# |||271496|6881|
# |||47890|165|
# |||105288|1933|
# |||11|0|
# |||9106|146|
# |||10044957|130472|
# |||447308|8727|
# |||232974|228|
# |||3915992|6529|
# |||105111|91|
# |||1800236|2783|
# |||883620|1365|
# |||287507|256|
# |||2880559|7370|
# |||1293461|952|
# |||5961143|21970|
# |||828825|10138|
# |||37491|833|
# |||710693|1553|
# |||2037871|29445|
# |||106798|579|
# |||994037|7118|
# |||4739365|33814|
# |||70757|688|
# |||27999|163|
# |||62627|21|
# |||1194277|22365|
# |||401729|16280|
# |||329758|2801|
# |||37076053|699276|
# |||279661|225|
# |||1297523|38228|
# |||22056|396|
# |||633950|19490|
# |||53631|38|
# |||63244|413|
# |||138719|3056|
# |||124392|1965|
# |||629269|5622|
# |||396817|5249|
# |||0|1|
# |||13|0|
# |||154712|2464|
# |||88866|834|
# |||54757|318|
# |||11511|22|
# |||140793|794|
# |||3531|7|
# |||1601325|16234|
# |||56523|93|
# |||1320325|18160|
# |||153651|1890|
# |||4989|32|
# |||15368|113|
# |||7679|194|
# |||5192286|64273|
# |||2275|7|
# |||40774|20|
# |||14715|11|
# |||17122|2|
# |||1742|2|
# |||103248|10|
# |||13371|2|
# |||2534|2|
# |||10483|6|
# |||3292|7|
# |||6603|18|
# |||9589|123|
# |||16607|29|
# |||23616|122|
# |||6281|77|
# |||830127|9618|
# |||88926|1971|
# |||2500142|17881|
# |||50665|172|
# |||7760|126|
# |||2235294|1722|
# |||2667551|21035|
# |||1331707|7078|
# |||24575|153|
# |||27324|1361|
# |||4067067|102595|
# |||18368|138|
# |||13770429|119479|
# |||672039|16830|
# |||63829|5017|
# |||865|0|
# |||82467|1404|
# |||2699339|23777|
# |||4413911|14210|
# |||57467|3164|
# |||17786|125|
# |||42906|846|
# |||4728182|33918|
# |||23419|138|
# |||39396|290|
# |||16810|13|
# |||189918|4355|
# |||1151126|29341|
# |||17042722|101492|
# |||2805|0|
# |||103802702|1123836|
# |||170544|3630|
# |||5711929|119283|
# |||1053213|2349|
# |||3904|12|
# |||18828|160|
# |||7305|64|
# |||31472|37|
# |||0|0|
# |||1930|0|
# |||20433|111|
# |||34991|66|
# |||38008|116|
# |||66391|161|
# |||1403|8|
# |||24425309|219948|
# |||4|0|
# |||2166|0|
# |||6561|38|
# |||1034303|7617|
# |||251247|1637|
# |||12014|14|
# |||552162|5854|
# |||11526994|43186|
# |||703228|5708|
# |||535|0|
# |||11945|2159|
# |||343135|4057|
# |||264276|5671|

# %% [markdown]
# ## 0409 承接 0405 與 0406 在 `covid19` 資料庫中，建立 `views_right_joined` 檢視表，使用 `RIGHT JOIN` 連接兩個檢視表，以 `accumulative_cases_20230309` 作為左檢視表、`locations_twn_jpn` 作為右檢視表，連接後的檢視表內容如下所示。
#
# |country_name|province_name|confirmed|deaths|
# |------------|-------------|---------|------|
# |Japan|Aichi|||
# |Japan|Akita|||
# |Japan|Aomori|||
# |Japan|Chiba|||
# |Japan|Ehime|||
# |Japan|Fukui|||
# |Japan|Fukuoka|||
# |Japan|Fukushima|||
# |Japan|Gifu|||
# |Japan|Gunma|||
# |Japan|Hiroshima|||
# |Japan|Hokkaido|||
# |Japan|Hyogo|||
# |Japan|Ibaraki|||
# |Japan|Ishikawa|||
# |Japan|Iwate|||
# |Japan|Kagawa|||
# |Japan|Kagoshima|||
# |Japan|Kanagawa|||
# |Japan|Kochi|||
# |Japan|Kumamoto|||
# |Japan|Kyoto|||
# |Japan|Mie|||
# |Japan|Miyagi|||
# |Japan|Miyazaki|||
# |Japan|Nagano|||
# |Japan|Nagasaki|||
# |Japan|Nara|||
# |Japan|Niigata|||
# |Japan||33320438|72997|
# |Japan|Oita|||
# |Japan|Okayama|||
# |Japan|Okinawa|||
# |Japan|Osaka|||
# |Japan|Port Quarantine|||
# |Japan|Saga|||
# |Japan|Saitama|||
# |Japan|Shiga|||
# |Japan|Shimane|||
# |Japan|Shizuoka|||
# |Japan|Tochigi|||
# |Japan|Tokushima|||
# |Japan|Tokyo|||
# |Japan|Tottori|||
# |Japan|Toyama|||
# |Japan|Wakayama|||
# |Japan|Yamagata|||
# |Japan|Yamaguchi|||
# |Japan|Yamanashi|||
# |Taiwan||9970937|17672|

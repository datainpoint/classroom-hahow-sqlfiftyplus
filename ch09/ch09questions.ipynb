# %% [markdown]
# # 進階的 SQL 五十道練習
#
# > 進階的 SQL 查詢
#
# [數聚點](https://www.datainpoint.com) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 仔細閱讀題目敘述並且在自己的電腦透過 DBeaver 完成。
# - 下載批改測試檔案並放置在自己熟悉的目錄（資料夾）之中。
#     - 批改測試檔案：[ch09-test-advanced-query.py](https://classroom-hahow-sqlfiftyplus.s3.ap-northeast-1.amazonaws.com/test_scripts/ch09-test-advanced-query.py)
# - 執行測試：
#     - 開啟 Anaconda Prompt（Windows 作業系統）或 Terminal（macOS）
#     - 啟動專案環境 `conda activate pythonmysql`
#     - 透過 `cd` 指令移動到放置批改測試檔案的目錄（資料夾）。
#     - 執行 `python ch09-test-advanced-query.py root {roots_password}`
# - 終端機操作的技巧：
#     - 在終端機畫面中按「向上箭頭」可以叫出先前執行過的指令。
#     - Windows 作業系統可以使用 `cls` 指令清空 Anaconda Prompt 畫面；macOS 可以使用 `clear` 指令或 `Ctrl - L` 清空 Terminal 畫面。

# %% [markdown]
# ## 0901 在本機 MySQL Server 的 `covid19` 資料庫，建立一個檢視表 `date_difference` 顯示 `accumulative_cases` 資料表與 `calendars` 資料表兩者的日期資料差集，亦即哪些日期在 `calendars` 資料表之中，卻沒有出現在 `accumulative_cases` 資料表中。
#
# ```sql
# SELECT *
#   FROM covid19.date_difference;
# ```
#
# |id|recorded_on|
# |--|-----------|
# |1|2020-01-01|
# |2|2020-01-02|
# |3|2020-01-03|
# |4|2020-01-04|
# |5|2020-01-05|
# |6|2020-01-06|
# |7|2020-01-07|
# |8|2020-01-08|
# |9|2020-01-09|
# |10|2020-01-10|
# |11|2020-01-11|
# |12|2020-01-12|
# |13|2020-01-13|
# |14|2020-01-14|
# |15|2020-01-15|
# |16|2020-01-16|
# |17|2020-01-17|
# |18|2020-01-18|
# |19|2020-01-19|
# |20|2020-01-20|
# |21|2020-01-21|
# |1165|2023-03-10|
# |1166|2023-03-11|
# |1167|2023-03-12|
# |1168|2023-03-13|
# |1169|2023-03-14|
# |1170|2023-03-15|
# |1171|2023-03-16|
# |1172|2023-03-17|
# |1173|2023-03-18|
# |1174|2023-03-19|
# |1175|2023-03-20|
# |1176|2023-03-21|
# |1177|2023-03-22|
# |1178|2023-03-23|
# |1179|2023-03-24|
# |1180|2023-03-25|
# |1181|2023-03-26|
# |1182|2023-03-27|
# |1183|2023-03-28|
# |1184|2023-03-29|
# |1185|2023-03-30|
# |1186|2023-03-31|
# |1187|2023-04-01|
# |1188|2023-04-02|
# |1189|2023-04-03|
# |1190|2023-04-04|
# |1191|2023-04-05|
# |1192|2023-04-06|
# |1193|2023-04-07|
# |1194|2023-04-08|
# |1195|2023-04-09|
# |1196|2023-04-10|
# |1197|2023-04-11|
# |1198|2023-04-12|
# |1199|2023-04-13|
# |1200|2023-04-14|
# |1201|2023-04-15|
# |1202|2023-04-16|
# |1203|2023-04-17|
# |1204|2023-04-18|
# |1205|2023-04-19|
# |1206|2023-04-20|
# |1207|2023-04-21|
# |1208|2023-04-22|
# |1209|2023-04-23|
# |1210|2023-04-24|
# |1211|2023-04-25|
# |1212|2023-04-26|
# |1213|2023-04-27|
# |1214|2023-04-28|
# |1215|2023-04-29|
#   FROM tw_election_2020.presidential_votes_percentage;
# ```
#
# |num|name|votes|total_votes|votes_percentage|
# |---|----|-----|-----------|----------------|
# |1|宋楚瑜/余湘|608590|14300940|0.0426|
# |2|韓國瑜/張善政|5522119|14300940|0.3861|
# |3|蔡英文/賴清德|8170231|14300940|0.5713|

# %% [markdown]
# ## 0903 在本機 MySQL Server 的 `tw_election_2020` 資料庫，建立一個檢視表 `legislative_at_large_votes_percentage` 顯示每個政黨的不分區立委得票比例。
#
# ```sql
# SELECT *
#   FROM tw_election_2020.legislative_at_large_votes_percentage;
# ```
#
# |name|votes|total_votes|votes_percentage|
# |----|-----|-----------|----------------|
# |民主進步黨|4811241|14160138|0.3398|
# |中國國民黨|4723504|14160138|0.3336|
# |台灣民眾黨|1588806|14160138|0.1122|
# |時代力量|1098100|14160138|0.0775|
# |親民黨|518921|14160138|0.0366|
# |台灣基進|447286|14160138|0.0316|
# |綠黨|341465|14160138|0.0241|
# |新黨|147373|14160138|0.0104|
# |一邊一國行動黨|143617|14160138|0.0101|
# |安定力量|94563|14160138|0.0067|
# |台灣團結聯盟|50435|14160138|0.0036|
# |國會政黨聯盟|40331|14160138|0.0028|
# |中華統一促進黨|32966|14160138|0.0023|
# |宗教聯盟|31117|14160138|0.0022|
# |喜樂島聯盟|29324|14160138|0.0021|
# |勞動黨|19941|14160138|0.0014|
# |合一行動聯盟|17515|14160138|0.0012|
# |台灣維新|11952|14160138|0.0008|
# |台澎黨|11681|14160138|0.0008|

# %% [markdown]
# ## 0904 在本機 MySQL Server 的 `covid19` 資料庫，建立一個檢視表 `most_populated_province` 顯示 `locations` 資料表每個國家人口數最多的州別（或省份），沒有切分州別（或省份）資料的國家不需要包含在該檢視表中。
#
# ```sql
# SELECT *
#   FROM covid19.most_populated_province;
# ```
#
# |country_name|most_populated_province_name|
# |------------|---------------------|
# |Australia|New South Wales|
# |Belgium|Antwerp|
# |Brazil|Sao Paulo|
# |Canada|Ontario|
# |Chile|Metropolitana|
# |China|Guangdong|
# |Colombia|Capital District|
# |Denmark|Greenland|
# |France|Reunion|
# |Germany|Nordrhein-Westfalen|
# |India|Uttar Pradesh|
# |Italy|Lombardia|
# |Japan|Tokyo|
# |Malaysia|Selangor|
# |Mexico|Mexico|
# |Moldova|Chisinau|
# |Netherlands|Zuid-Holland|
# |New Zealand|Cook Islands|
# |Nigeria|Kano|
# |Pakistan|Punjab|
# |Peru|Lima|
# |Poland|Mazowieckie|
# |Romania|Bucuresti|
# |Russia|Moscow|
# |Slovakia|Presov|
# |Spain|Andalusia|
# |Sweden|Stockholm|
# |Ukraine|Donetsk Oblast|
# |United Kingdom|England|
# |US|California|

# %% [markdown]
# ## 0905 在本機 MySQL Server 的 `covid19` 資料庫，建立一個檢視表 `daily_cases` 顯示每個 `location_id`、`calendar_id` 的每日新增個案數。
#
# ```sql
# SELECT *
#   FROM covid19.daily_cases;
# ```
#
# |location_id|calendar_id|confirmed|deaths|
# |-----------|-----------|---------|------|
# |1|22|NULL|NULL|
# |1|23|0|0|
# |1|24|0|0|
# |1|25|0|0|
# |1|26|0|0|
# ...|...|...|...|
# |955|1160|0|0|
# |955|1161|0|0|
# |955|1162|0|0|
# |955|1163|149|3|
# |955|1164|0|0|
#
# `(328041, 4)`
